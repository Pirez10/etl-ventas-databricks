# %%
# %run ./transformations

# %%
def log(msg):
    print(f"[LOG] {msg}")

def validar_df(df, nombre="df"):
    count = df.count()
    print(f"[INFO] {nombre} tiene {count} registros")
    if count == 0:
        raise Exception(f"{nombre} está vacío!")
